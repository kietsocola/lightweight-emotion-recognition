# %% [markdown]
# # 📌 Gamma Correction – Điều chỉnh Gamma trong xử lý ảnh
#
# ---
#
# ## 1️⃣ Gamma là gì?
#
# Gamma (γ) là một tham số kiểm soát độ sáng và độ tương phản của hình ảnh bằng cách thay đổi cách ánh sáng được ánh xạ từ đầu vào sang đầu ra.
#
# ### 🔹 Công thức Gamma Correction:
# $$
# I_{\text{new}} = 255 \times \left( \frac{I_{\text{old}}}{255} \right)^{\frac{1}{\gamma}}
# $$
#
# - $I_{\text{old}}$ là giá trị pixel ban đầu (0-255).
# - $I_{\text{new}}$ là giá trị pixel sau khi áp dụng gamma correction.
# - $\gamma$ là giá trị gamma.
#
# ---
#
# ## 2️⃣ Ảnh hưởng của Gamma Correction
#
# - Nếu **$\gamma > 1$** → Ảnh sẽ **sáng hơn**.
# - Nếu **$\gamma < 1$** → Ảnh sẽ **tối hơn**.
#
# Ví dụ:
#
# | Giá trị Gamma | Ảnh đầu ra |
# |--------------|------------|
# | **$\gamma = 0.5$** | Ảnh tối hơn |
# | **$\gamma = 1$** | Không thay đổi |
# | **$\gamma = 2.2$** | Ảnh sáng hơn |
#
# ---
#
# ## 3️⃣ Code Python minh họa Gamma Correction

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Hàm điều chỉnh Gamma Correction
def adjust_gamma(image, gamma=1.0):
    inv_gamma = 1.0 / gamma
    table = np.array([(i / 255.0) ** inv_gamma * 255 for i in range(256)]).astype("uint8")
    return cv2.LUT(image, table)

# Đọc ảnh gốc (cần có sẵn file ảnh)
image = cv2.imread("dark_image.png")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Chuyển ảnh từ BGR sang RGB để hiển thị đúng màu

# Áp dụng Gamma Correction
gamma_corrected = adjust_gamma(image, gamma=2.2)

# Hiển thị ảnh gốc và ảnh đã xử lý
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(image)
plt.title("Ảnh Gốc")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(gamma_corrected)
plt.title("Ảnh Sau Gamma Correction")
plt.axis("off")

plt.show()
