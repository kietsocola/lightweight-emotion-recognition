# %% [markdown]
# # ex1_scientific1
# ## Nội dung bài
# Hiển thị ngẫu nhiên $N=50$ hình tròn
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0, 1 \right]$
# + Màu sắc $color_i$ ngẫu nhiên với $color_i \in \left[0, 1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in  \left[0, 1 \right]$
# ## Bài làm

# %% [markdown]
# ## Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# %time
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N)) ** 2
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
print(f'+ x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples {x[:10]}')
print(f'+ y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples {y[:10]}')
print(f'+ colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples {colors[:10]}')
print(f'+ area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples {area[:10]}')
# Out:
# + x: len=50, [0.00, 0.99]: 10 samples [0.52480715 0.43252402 0.38989258 0.73025412 0.8232957  0.29955476
#  0.84681192 0.98561447 0.89922545 0.77367593]
# + y: len=50, [0.00, 0.95]: 10 samples [0.09803402 0.00255763 0.68661499 0.00794009 0.93567193 0.20741054
#  0.72724106 0.833818   0.48886056 0.59824535]
# + colors: len=50, [0.02, 1.00]: 10 samples [0.92999802 0.20846788 0.69700722 0.6210757  0.34263502 0.54807878
#  0.9982882  0.96907334 0.27256226 0.21076995]
# + area: len=50, [0.01, 705.22]: 10 samples [100.12852614 654.43916198  17.22465697 384.89267964 193.80609565
#  213.8574546  288.04599948  66.91432557   1.52819086 141.02081421]

# %% [markdown]
# ### Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# # Kết thúc
