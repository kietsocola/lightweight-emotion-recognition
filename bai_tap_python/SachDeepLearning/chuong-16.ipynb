# %% [markdown]
# # Keep The Bests models During Training with Checkpointing

# %% [markdown]
# ## 16.2 Checkpoint Neural Network Model Improvements

# %%
# Checkpoint the weights when validation accuracy improves
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
tf.random.set_seed(42)
# load pima indians dataset
dataset = np.loadtxt("pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# create model
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# checkpoint
filepath="weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,

save_best_only=True, mode='max')

# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10,

callbacks=[checkpoint], verbose=0)
# Out:
# Epoch 1: val_accuracy improved from -inf to 0.65354, saving model to weights-improvement-01-0.65.hdf5
#
# Epoch 2: val_accuracy did not improve from 0.65354
#
# Epoch 3: val_accuracy did not improve from 0.65354
# /Users/nguyenhuuloc/Downloads/DO_AN_PPNCKH/keras-py310/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 4: val_accuracy did not improve from 0.65354
#
# Epoch 5: val_accuracy did not improve from 0.65354
#
# Epoch 6: val_accuracy did not improve from 0.65354
#
# Epoch 7: val_accuracy improved from 0.65354 to 0.65748, saving model to weights-improvement-07-0.66.hdf5
#
# Epoch 8: val_accuracy did not improve from 0.65748
#
# Epoch 9: val_accuracy did not improve from 0.65748
#
# Epoch 10: val_accuracy did not improve from 0.65748
#
# Epoch 11: val_accuracy did not improve from 0.65748
#
# Epoch 12: val_accuracy did not improve from 0.65748
#
# Epoch 13: val_accuracy did not improve from 0.65748
#
# Epoch 14: val_accuracy did not improve from 0.65748
#
# Epoch 15: val_accuracy did not improve from 0.65748
#
# Epoch 16: val_accuracy did not improve from 0.65748
#
# Epoch 17: val_accuracy did not improve from 0.65748
#
# Epoch 18: val_accuracy did not improve from 0.65748
#
# Epoch 19: val_accuracy did not improve from 0.65748
#
# Epoch 20: val_accuracy did not improve from 0.65748
#
# Epoch 21: val_accuracy did not improve from 0.65748
#
# Epoch 22: val_accuracy did not improve from 0.65748
#
# Epoch 23: val_accuracy did not improve from 0.65748
#
# Epoch 24: val_accuracy did not improve from 0.65748
#
# Epoch 25: val_accuracy improved from 0.65748 to 0.69291, saving model to weights-improvement-25-0.69.hdf5
#
# Epoch 26: val_accuracy did not improve from 0.69291
#
# Epoch 27: val_accuracy did not improve from 0.69291
#
# Epoch 28: val_accuracy did not improve from 0.69291
#
# Epoch 29: val_accuracy did not improve from 0.69291
#
# Epoch 30: val_accuracy did not improve from 0.69291
#
# Epoch 31: val_accuracy did not improve from 0.69291
#
# Epoch 32: val_accuracy did not improve from 0.69291
#
# Epoch 33: val_accuracy did not improve from 0.69291
#
# Epoch 34: val_accuracy did not improve from 0.69291
#
# Epoch 35: val_accuracy did not improve from 0.69291
#
# Epoch 36: val_accuracy did not improve from 0.69291
#
# Epoch 37: val_accuracy did not improve from 0.69291
#
# Epoch 38: val_accuracy did not improve from 0.69291
#
# Epoch 39: val_accuracy did not improve from 0.69291
#
# Epoch 40: val_accuracy did not improve from 0.69291
#
# Epoch 41: val_accuracy did not improve from 0.69291
#
# Epoch 42: val_accuracy did not improve from 0.69291
#
# Epoch 43: val_accuracy did not improve from 0.69291
#
# Epoch 44: val_accuracy improved from 0.69291 to 0.70079, saving model to weights-improvement-44-0.70.hdf5
#
# Epoch 45: val_accuracy did not improve from 0.70079
#
# Epoch 46: val_accuracy did not improve from 0.70079
#
# Epoch 47: val_accuracy did not improve from 0.70079
#
# Epoch 48: val_accuracy did not improve from 0.70079
#
# Epoch 49: val_accuracy did not improve from 0.70079
#
# Epoch 50: val_accuracy did not improve from 0.70079
#
# Epoch 51: val_accuracy improved from 0.70079 to 0.71654, saving model to weights-improvement-51-0.72.hdf5
#
# Epoch 52: val_accuracy did not improve from 0.71654
#
# Epoch 53: val_accuracy did not improve from 0.71654
#
# Epoch 54: val_accuracy did not improve from 0.71654
#
# Epoch 55: val_accuracy did not improve from 0.71654
#
# Epoch 56: val_accuracy did not improve from 0.71654
#
# Epoch 57: val_accuracy did not improve from 0.71654
#
# Epoch 58: val_accuracy did not improve from 0.71654
#
# Epoch 59: val_accuracy did not improve from 0.71654
#
# Epoch 60: val_accuracy did not improve from 0.71654
#
# Epoch 61: val_accuracy did not improve from 0.71654
#
# Epoch 62: val_accuracy improved from 0.71654 to 0.73228, saving model to weights-improvement-62-0.73.hdf5
#
# Epoch 63: val_accuracy did not improve from 0.73228
#
# Epoch 64: val_accuracy did not improve from 0.73228
#
# Epoch 65: val_accuracy did not improve from 0.73228
#
# Epoch 66: val_accuracy did not improve from 0.73228
#
# Epoch 67: val_accuracy did not improve from 0.73228
#
# Epoch 68: val_accuracy did not improve from 0.73228
#
# Epoch 69: val_accuracy did not improve from 0.73228
#
# Epoch 70: val_accuracy did not improve from 0.73228
#
# Epoch 71: val_accuracy did not improve from 0.73228
#
# Epoch 72: val_accuracy did not improve from 0.73228
#
# Epoch 73: val_accuracy did not improve from 0.73228
#
# Epoch 74: val_accuracy did not improve from 0.73228
#
# Epoch 75: val_accuracy did not improve from 0.73228
#
# Epoch 76: val_accuracy did not improve from 0.73228
#
# Epoch 77: val_accuracy did not improve from 0.73228
#
# Epoch 78: val_accuracy did not improve from 0.73228
#
# Epoch 79: val_accuracy did not improve from 0.73228
#
# Epoch 80: val_accuracy did not improve from 0.73228
#
# Epoch 81: val_accuracy did not improve from 0.73228
#
# Epoch 82: val_accuracy did not improve from 0.73228
#
# Epoch 83: val_accuracy did not improve from 0.73228
#
# Epoch 84: val_accuracy did not improve from 0.73228
#
# Epoch 85: val_accuracy did not improve from 0.73228
#
# Epoch 86: val_accuracy improved from 0.73228 to 0.75197, saving model to weights-improvement-86-0.75.hdf5
#
# Epoch 87: val_accuracy did not improve from 0.75197
#
# Epoch 88: val_accuracy did not improve from 0.75197
#
# Epoch 89: val_accuracy did not improve from 0.75197
#
# Epoch 90: val_accuracy did not improve from 0.75197
#
# Epoch 91: val_accuracy did not improve from 0.75197
#
# Epoch 92: val_accuracy did not improve from 0.75197
#
# Epoch 93: val_accuracy improved from 0.75197 to 0.75984, saving model to weights-improvement-93-0.76.hdf5
#
# Epoch 94: val_accuracy did not improve from 0.75984
#
# Epoch 95: val_accuracy did not improve from 0.75984
#
# Epoch 96: val_accuracy did not improve from 0.75984
#
# Epoch 97: val_accuracy did not improve from 0.75984
#
# Epoch 98: val_accuracy did not improve from 0.75984
#
# Epoch 99: val_accuracy did not improve from 0.75984
#
# Epoch 100: val_accuracy did not improve from 0.75984
#
# Epoch 101: val_accuracy did not improve from 0.75984
#
# Epoch 102: val_accuracy did not improve from 0.75984
#
# Epoch 103: val_accuracy improved from 0.75984 to 0.77559, saving model to weights-improvement-103-0.78.hdf5
#
# Epoch 104: val_accuracy did not improve from 0.77559
#
# Epoch 105: val_accuracy did not improve from 0.77559
#
# Epoch 106: val_accuracy did not improve from 0.77559
#
# Epoch 107: val_accuracy did not improve from 0.77559
#
# Epoch 108: val_accuracy did not improve from 0.77559
#
# Epoch 109: val_accuracy did not improve from 0.77559
#
# Epoch 110: val_accuracy did not improve from 0.77559
#
# Epoch 111: val_accuracy did not improve from 0.77559
#
# Epoch 112: val_accuracy did not improve from 0.77559
#
# Epoch 113: val_accuracy did not improve from 0.77559
#
# Epoch 114: val_accuracy did not improve from 0.77559
#
# Epoch 115: val_accuracy did not improve from 0.77559
#
# Epoch 116: val_accuracy did not improve from 0.77559
#
# Epoch 117: val_accuracy did not improve from 0.77559
#
# Epoch 118: val_accuracy did not improve from 0.77559
#
# Epoch 119: val_accuracy did not improve from 0.77559
#
# Epoch 120: val_accuracy did not improve from 0.77559
#
# Epoch 121: val_accuracy did not improve from 0.77559
#
# Epoch 122: val_accuracy did not improve from 0.77559
#
# Epoch 123: val_accuracy did not improve from 0.77559
#
# Epoch 124: val_accuracy did not improve from 0.77559
#
# Epoch 125: val_accuracy did not improve from 0.77559
#
# Epoch 126: val_accuracy did not improve from 0.77559
#
# Epoch 127: val_accuracy did not improve from 0.77559
#
# Epoch 128: val_accuracy did not improve from 0.77559
#
# Epoch 129: val_accuracy did not improve from 0.77559
#
# Epoch 130: val_accuracy did not improve from 0.77559
#
# Epoch 131: val_accuracy did not improve from 0.77559
#
# Epoch 132: val_accuracy did not improve from 0.77559
#
# Epoch 133: val_accuracy did not improve from 0.77559
#
# Epoch 134: val_accuracy did not improve from 0.77559
#
# Epoch 135: val_accuracy did not improve from 0.77559
#
# Epoch 136: val_accuracy did not improve from 0.77559
#
# Epoch 137: val_accuracy did not improve from 0.77559
#
# Epoch 138: val_accuracy did not improve from 0.77559
#
# Epoch 139: val_accuracy did not improve from 0.77559
#
# Epoch 140: val_accuracy did not improve from 0.77559
#
# Epoch 141: val_accuracy did not improve from 0.77559
#
# Epoch 142: val_accuracy did not improve from 0.77559
#
# Epoch 143: val_accuracy did not improve from 0.77559
#
# Epoch 144: val_accuracy did not improve from 0.77559
#
# Epoch 145: val_accuracy did not improve from 0.77559
#
# Epoch 146: val_accuracy did not improve from 0.77559
#
# Epoch 147: val_accuracy did not improve from 0.77559
#
# Epoch 148: val_accuracy did not improve from 0.77559
#
# Epoch 149: val_accuracy did not improve from 0.77559
#
# Epoch 150: val_accuracy did not improve from 0.77559

# %%
# Checkpoint the weights for best model on validation accuracy
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import numpy as np
# load pima indians dataset
dataset = np.loadtxt("pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# create model
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# checkpoint
filepath="weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,

save_best_only=True, mode='max')

callbacks_list = [checkpoint]
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10,

callbacks=callbacks_list, verbose=0)
# Out:
# Epoch 1: val_accuracy improved from -inf to 0.53937, saving model to weights.best.hdf5
#
# Epoch 2: val_accuracy improved from 0.53937 to 0.57480, saving model to weights.best.hdf5
#
# Epoch 3: val_accuracy did not improve from 0.57480
#
# Epoch 4: val_accuracy improved from 0.57480 to 0.59055, saving model to weights.best.hdf5
#
# Epoch 5: val_accuracy did not improve from 0.59055
#
# Epoch 6: val_accuracy did not improve from 0.59055
#
# Epoch 7: val_accuracy did not improve from 0.59055
#
# Epoch 8: val_accuracy did not improve from 0.59055
#
# Epoch 9: val_accuracy did not improve from 0.59055
#
# Epoch 10: val_accuracy did not improve from 0.59055
#
# Epoch 11: val_accuracy did not improve from 0.59055
#
# Epoch 12: val_accuracy improved from 0.59055 to 0.62992, saving model to weights.best.hdf5
#
# Epoch 13: val_accuracy improved from 0.62992 to 0.64567, saving model to weights.best.hdf5
#
# Epoch 14: val_accuracy did not improve from 0.64567
#
# Epoch 15: val_accuracy did not improve from 0.64567
#
# Epoch 16: val_accuracy did not improve from 0.64567
#
# Epoch 17: val_accuracy did not improve from 0.64567
#
# Epoch 18: val_accuracy improved from 0.64567 to 0.65748, saving model to weights.best.hdf5
#
# Epoch 19: val_accuracy did not improve from 0.65748
#
# Epoch 20: val_accuracy did not improve from 0.65748
#
# Epoch 21: val_accuracy did not improve from 0.65748
#
# Epoch 22: val_accuracy did not improve from 0.65748
#
# Epoch 23: val_accuracy did not improve from 0.65748
#
# Epoch 24: val_accuracy did not improve from 0.65748
#
# Epoch 25: val_accuracy did not improve from 0.65748
#
# Epoch 26: val_accuracy did not improve from 0.65748
#
# Epoch 27: val_accuracy did not improve from 0.65748
#
# Epoch 28: val_accuracy did not improve from 0.65748
#
# Epoch 29: val_accuracy did not improve from 0.65748
#
# Epoch 30: val_accuracy did not improve from 0.65748
#
# Epoch 31: val_accuracy did not improve from 0.65748
#
# Epoch 32: val_accuracy did not improve from 0.65748
#
# Epoch 33: val_accuracy did not improve from 0.65748
#
# Epoch 34: val_accuracy did not improve from 0.65748
#
# Epoch 35: val_accuracy improved from 0.65748 to 0.66535, saving model to weights.best.hdf5
#
# Epoch 36: val_accuracy did not improve from 0.66535
#
# Epoch 37: val_accuracy did not improve from 0.66535
#
# Epoch 38: val_accuracy did not improve from 0.66535
#
# Epoch 39: val_accuracy did not improve from 0.66535
#
# Epoch 40: val_accuracy improved from 0.66535 to 0.68504, saving model to weights.best.hdf5
#
# Epoch 41: val_accuracy did not improve from 0.68504
#
# Epoch 42: val_accuracy did not improve from 0.68504
#
# Epoch 43: val_accuracy did not improve from 0.68504
#
# Epoch 44: val_accuracy improved from 0.68504 to 0.70079, saving model to weights.best.hdf5
#
# Epoch 45: val_accuracy did not improve from 0.70079
#
# Epoch 46: val_accuracy did not improve from 0.70079
#
# Epoch 47: val_accuracy did not improve from 0.70079
#
# Epoch 48: val_accuracy did not improve from 0.70079
#
# Epoch 49: val_accuracy did not improve from 0.70079
#
# Epoch 50: val_accuracy did not improve from 0.70079
#
# Epoch 51: val_accuracy did not improve from 0.70079
#
# Epoch 52: val_accuracy did not improve from 0.70079
#
# Epoch 53: val_accuracy did not improve from 0.70079
#
# Epoch 54: val_accuracy did not improve from 0.70079
#
# Epoch 55: val_accuracy did not improve from 0.70079
#
# Epoch 56: val_accuracy did not improve from 0.70079
#
# Epoch 57: val_accuracy did not improve from 0.70079
#
# Epoch 58: val_accuracy did not improve from 0.70079
#
# Epoch 59: val_accuracy did not improve from 0.70079
#
# Epoch 60: val_accuracy did not improve from 0.70079
#
# Epoch 61: val_accuracy improved from 0.70079 to 0.70472, saving model to weights.best.hdf5
#
# Epoch 62: val_accuracy did not improve from 0.70472
#
# Epoch 63: val_accuracy did not improve from 0.70472
#
# Epoch 64: val_accuracy did not improve from 0.70472
#
# Epoch 65: val_accuracy improved from 0.70472 to 0.70866, saving model to weights.best.hdf5
#
# Epoch 66: val_accuracy improved from 0.70866 to 0.71654, saving model to weights.best.hdf5
#
# Epoch 67: val_accuracy did not improve from 0.71654
#
# Epoch 68: val_accuracy did not improve from 0.71654
#
# Epoch 69: val_accuracy did not improve from 0.71654
#
# Epoch 70: val_accuracy did not improve from 0.71654
#
# Epoch 71: val_accuracy did not improve from 0.71654
#
# Epoch 72: val_accuracy did not improve from 0.71654
#
# Epoch 73: val_accuracy did not improve from 0.71654
#
# Epoch 74: val_accuracy did not improve from 0.71654
#
# Epoch 75: val_accuracy did not improve from 0.71654
#
# Epoch 76: val_accuracy did not improve from 0.71654
#
# Epoch 77: val_accuracy did not improve from 0.71654
#
# Epoch 78: val_accuracy did not improve from 0.71654
#
# Epoch 79: val_accuracy did not improve from 0.71654
#
# Epoch 80: val_accuracy did not improve from 0.71654
#
# Epoch 81: val_accuracy did not improve from 0.71654
#
# Epoch 82: val_accuracy did not improve from 0.71654
#
# Epoch 83: val_accuracy did not improve from 0.71654
#
# Epoch 84: val_accuracy did not improve from 0.71654
#
# Epoch 85: val_accuracy did not improve from 0.71654
#
# Epoch 86: val_accuracy improved from 0.71654 to 0.72441, saving model to weights.best.hdf5
#
# Epoch 87: val_accuracy did not improve from 0.72441
#
# Epoch 88: val_accuracy did not improve from 0.72441
#
# Epoch 89: val_accuracy did not improve from 0.72441
#
# Epoch 90: val_accuracy did not improve from 0.72441
#
# Epoch 91: val_accuracy improved from 0.72441 to 0.72835, saving model to weights.best.hdf5
#
# Epoch 92: val_accuracy did not improve from 0.72835
#
# Epoch 93: val_accuracy did not improve from 0.72835
#
# Epoch 94: val_accuracy did not improve from 0.72835
#
# Epoch 95: val_accuracy did not improve from 0.72835
#
# Epoch 96: val_accuracy did not improve from 0.72835
#
# Epoch 97: val_accuracy did not improve from 0.72835
#
# Epoch 98: val_accuracy did not improve from 0.72835
#
# Epoch 99: val_accuracy improved from 0.72835 to 0.73228, saving model to weights.best.hdf5
#
# Epoch 100: val_accuracy did not improve from 0.73228
#
# Epoch 101: val_accuracy did not improve from 0.73228
#
# Epoch 102: val_accuracy did not improve from 0.73228
#
# Epoch 103: val_accuracy did not improve from 0.73228
#
# Epoch 104: val_accuracy did not improve from 0.73228
#
# Epoch 105: val_accuracy did not improve from 0.73228
#
# Epoch 106: val_accuracy improved from 0.73228 to 0.74409, saving model to weights.best.hdf5
#
# Epoch 107: val_accuracy did not improve from 0.74409
#
# Epoch 108: val_accuracy did not improve from 0.74409
#
# Epoch 109: val_accuracy did not improve from 0.74409
#
# Epoch 110: val_accuracy improved from 0.74409 to 0.75984, saving model to weights.best.hdf5
#
# Epoch 111: val_accuracy did not improve from 0.75984
#
# Epoch 112: val_accuracy did not improve from 0.75984
#
# Epoch 113: val_accuracy did not improve from 0.75984
#
# Epoch 114: val_accuracy did not improve from 0.75984
#
# Epoch 115: val_accuracy did not improve from 0.75984
#
# Epoch 116: val_accuracy did not improve from 0.75984
#
# Epoch 117: val_accuracy did not improve from 0.75984
#
# Epoch 118: val_accuracy improved from 0.75984 to 0.76772, saving model to weights.best.hdf5
#
# Epoch 119: val_accuracy did not improve from 0.76772
#
# Epoch 120: val_accuracy did not improve from 0.76772
#
# Epoch 121: val_accuracy did not improve from 0.76772
#
# Epoch 122: val_accuracy did not improve from 0.76772
#
# Epoch 123: val_accuracy did not improve from 0.76772
#
# Epoch 124: val_accuracy did not improve from 0.76772
#
# Epoch 125: val_accuracy did not improve from 0.76772
#
# Epoch 126: val_accuracy did not improve from 0.76772
#
# Epoch 127: val_accuracy did not improve from 0.76772
#
# Epoch 128: val_accuracy did not improve from 0.76772
#
# Epoch 129: val_accuracy did not improve from 0.76772
#
# Epoch 130: val_accuracy did not improve from 0.76772
#
# Epoch 131: val_accuracy did not improve from 0.76772
#
# Epoch 132: val_accuracy did not improve from 0.76772
#
# Epoch 133: val_accuracy did not improve from 0.76772
#
# Epoch 134: val_accuracy did not improve from 0.76772
#
# Epoch 135: val_accuracy did not improve from 0.76772
#
# Epoch 136: val_accuracy did not improve from 0.76772
#
# Epoch 137: val_accuracy did not improve from 0.76772
#
# Epoch 138: val_accuracy did not improve from 0.76772
#
# Epoch 139: val_accuracy did not improve from 0.76772
#
# Epoch 140: val_accuracy did not improve from 0.76772
#
# Epoch 141: val_accuracy did not improve from 0.76772
#
# Epoch 142: val_accuracy did not improve from 0.76772
#
# Epoch 143: val_accuracy did not improve from 0.76772
#
# Epoch 144: val_accuracy did not improve from 0.76772
#
# Epoch 145: val_accuracy did not improve from 0.76772
#
# Epoch 146: val_accuracy did not improve from 0.76772
#
# Epoch 147: val_accuracy did not improve from 0.76772
#
# Epoch 148: val_accuracy did not improve from 0.76772
#
# Epoch 149: val_accuracy did not improve from 0.76772
#
# Epoch 150: val_accuracy did not improve from 0.76772

# %% [markdown]
# ## 16.4 Use EarlyStopping Together with Checkpoint

# %%
# Checkpoint the weights for best model on validation accuracy
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt
import numpy as np
# load pima indians dataset
dataset = np.loadtxt("pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# create model
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# checkpoint
filepath="weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1,

save_best_only=True, mode='max')
es = EarlyStopping(monitor='val_accuracy', patience=5)
callbacks_list = [checkpoint, es]
# Fit the model
model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10,

callbacks=callbacks_list, verbose=0)
# Out:
# Epoch 1: val_accuracy improved from -inf to 0.56693, saving model to weights.best.hdf5
#
# Epoch 2: val_accuracy improved from 0.56693 to 0.64173, saving model to weights.best.hdf5
#
# Epoch 3: val_accuracy improved from 0.64173 to 0.64567, saving model to weights.best.hdf5
#
# Epoch 4: val_accuracy did not improve from 0.64567
#
# Epoch 5: val_accuracy did not improve from 0.64567
#
# Epoch 6: val_accuracy did not improve from 0.64567
#
# Epoch 7: val_accuracy did not improve from 0.64567
#
# Epoch 8: val_accuracy did not improve from 0.64567

# %% [markdown]
# ## 16.5 Loading a Saved Neural Network Model

# %%
# How to load and use weights from a checkpoint
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import numpy as np
# create model
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# load weights
model.load_weights("weights.best.hdf5")
# Compile model (required to make predictions)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print("Created model and loaded weights from file")
# load pima indians dataset
dataset = np.loadtxt("pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# estimate accuracy on whole dataset using loaded weights
scores = model.evaluate(X, Y, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# Created model and loaded weights from file
# accuracy: 63.54%
