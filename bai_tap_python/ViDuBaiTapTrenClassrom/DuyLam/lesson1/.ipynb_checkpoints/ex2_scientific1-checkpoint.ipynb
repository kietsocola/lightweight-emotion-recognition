# %% [markdown]
# # ex1_scientific1

# %% [markdown]
# ## Nội dung bài
# Hiển thị ngẫu nhiên $N=50$ hình tròn:
# + Tâm $c_i = (x_i,y_i)$ ngẫu nhiên với $x_i, y_i \in \left[0, 1 \right]$
# + Màu sắc $color i$ ngẫu nhiên với $color_i \in \left[0, 1 \right]$
# + Diện tích $area_i = \pi * r_i^2$ với sinh ngẫu nhiên $r_i \in \left[8, 1 \right]$

# %% [markdown]
# ## Bài làm

# %% [markdown]
# ### Import thư viện

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display # hiển thị rich output

# %% [markdown]
# ### Sinh ngẫu nhiên hình tròn

# %%
# %time
#generate randomly the center (x,y) of circle, color, area
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors= np.random.rand(N)
area = np.pi * (15* np.random.rand(N)) ** 2 # 0 to 15 point radii
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
# Mã kiểm tra dữ liệu
print (f'+x: len={len(x):d}, [{min(x):.2f}, {max(x):.2f}]: 10 samples [{x[0:10]}]')
print(f'+ y: len={len(y):d}, [{min(y):.2f}, {max(y):.2f}]: 10 samples [{y[0:10]}]')
print (f'+ colors: len={len(colors):d}, [{min(colors):.2f}, {max(colors):.2f}]: 10 samples [{colors[0:10]}]')
print (f'+ area: len={len(area):d}, [{min(area):.2f}, {max(area):.2f}]: 10 samples [{area [0:10]}]')
# Out:
# +x: len=50, [0.00, 0.96]: 10 samples [[0.23576161 0.34091735 0.45586087 0.58152278 0.54917762 0.02378797
#  0.08432996 0.24981083 0.56632889 0.52978374]]
# + y: len=50, [0.02, 0.99]: 10 samples [[0.46135113 0.27881904 0.91882176 0.46969231 0.30118506 0.62212182
#  0.13023685 0.57658886 0.84671419 0.39271726]]
# + colors: len=50, [0.02, 0.99]: 10 samples [[0.53960954 0.01589669 0.13243432 0.63278593 0.9119099  0.51286368
#  0.54959224 0.86570366 0.50528958 0.47239794]]
# + area: len=50, [0.67, 647.22]: 10 samples [[ 53.31926389 409.94938912   2.40015707  52.62390698 295.56973883
#  154.54889777 252.06167859 187.00448882 354.67714914 139.14826687]]

# %% [markdown]
# # Hiển thị đồ thị

# %%
# %matplotlib inline
plt.scatter(x, y, s=area, c=colors, alpha=0.5) 
plt.show()

# %% [markdown]
# # Kết thúc
